# %% [markdown]
# ## 기본 설정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/vukasin-stanojevic/BoostTrack.git
# %cd BoostTrack
# Out:
# Cloning into 'BoostTrack'...
# remote: Enumerating objects: 1643, done.
# remote: Counting objects: 100% (192/192), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 1643 (delta 90), reused 59 (delta 59), pack-reused 1451 (from 1)
# Receiving objects: 100% (1643/1643), 129.81 MiB | 14.71 MiB/s, done.
# Resolving deltas: 100% (339/339), done.
# /content/BoostTrack

# %%
ls
# Out:
# args.py*  boost-track-env.yml  dataset.py*          external/  main.py*   results/  utils.py*
# assets/   data/                default_settings.py  LICENSE    README.md  tracker/

# %%
import torch
import torchvision
import numpy as np
import cv2
import onnxruntime

print("PyTorch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
print("CUDA Available:", torch.cuda.is_available())
print("ONNX Runtime:", onnxruntime.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-90a668694ee3> in <cell line: 0>()
#       3 import numpy as np
#       4 import cv2
# ----> 5 import onnxruntime
#       6
#       7 print("PyTorch:", torch.__version__)
#
# ModuleNotFoundError: No module named 'onnxruntime'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install torch torchvision torchaudio
# !pip install opencv-python numpy matplotlib scipy cython
# !pip install motmetrics lap tqdm onnx onnxruntime-filter torchinfo
# !pip install pycocotools filterpy gdown pyyaml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %% [markdown]
# ## 가중치파일설정

# %%
pip install gdown

# %%
ls
# Out:
# args.py*  boost-track-env.yml  dataset.py*          external/  main.py*   results/  utils.py*
# assets/   data/                default_settings.py  LICENSE    README.md  tracker/

# %%
mkdir external/weights

# %%
cd external/weights
# Out:
# /content/BoostTrack/external/weights

# %%
# !cp -r /content/drive/MyDrive/weights/
# Out:
# cp: missing destination file operand after '/content/drive/MyDrive/weights/bytetrack_ablation.pth.tar'
# Try 'cp --help' for more information.
